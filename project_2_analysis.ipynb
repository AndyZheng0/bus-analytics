# %% [markdown]
# ## Imports

# %%
# Basic Imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Analysis Imports
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering, KMeans

# %% [markdown]
# ## EDA

# %%
df = pd.read_csv('data/IL_business.csv')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2145 entries, 0 to 2144
# Data columns (total 58 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   business_id                            2145 non-null   str
#  1   name                                   2145 non-null   str
#  2   address                                2122 non-null   str
#  3   city                                   2145 non-null   str
#  4   state                                  2145 non-null   str
#  5   postal_code                            2145 non-null   int64
#  6   latitude                               2145 non-null   float64
#  7   longitude                              2145 non-null   float64
#  8   stars                                  2145 non-null   float64
#  9   review_count                           2145 non-null   int64
#  10  is_open                                2145 non-null   int64
#  11  categories                             2144 non-null   str
#  12  attributes.ByAppointmentOnly           436 non-null    object
#  13  attributes.BusinessAcceptsCreditCards  1778 non-null   object
#  14  attributes.BikeParking                 1061 non-null   object
#  15  attributes.RestaurantsPriceRange2      1391 non-null   float64
#  16  attributes.CoatCheck                   98 non-null     object
#  17  attributes.RestaurantsTakeOut          1050 non-null   object
#  18  attributes.RestaurantsDelivery         982 non-null    object
#  19  attributes.Caters                      667 non-null    object
#  20  attributes.WiFi                        888 non-null    str
#  21  attributes.BusinessParking             1322 non-null   str
#  22  attributes.WheelchairAccessible        344 non-null    object
#  23  attributes.HappyHour                   179 non-null    object
#  24  attributes.OutdoorSeating              867 non-null    object
#  25  attributes.HasTV                       825 non-null    object
#  26  attributes.RestaurantsReservations     855 non-null    object
#  27  attributes.DogsAllowed                 209 non-null    object
#  28  attributes.Alcohol                     744 non-null    str
#  29  attributes.GoodForKids                 919 non-null    object
#  30  attributes.RestaurantsAttire           751 non-null    str
#  31  attributes.Ambience                    780 non-null    str
#  32  attributes.RestaurantsTableService     306 non-null    object
#  33  attributes.RestaurantsGoodForGroups    843 non-null    object
#  34  attributes.DriveThru                   194 non-null    object
#  35  attributes.NoiseLevel                  645 non-null    str
#  36  attributes.GoodForMeal                 510 non-null    str
#  37  attributes.BusinessAcceptsBitcoin      172 non-null    object
#  38  attributes.Smoking                     70 non-null     str
#  39  attributes.Music                       117 non-null    str
#  40  attributes.GoodForDancing              53 non-null     object
#  41  attributes.AcceptsInsurance            52 non-null     object
#  42  attributes.BestNights                  84 non-null     str
#  43  attributes.BYOB                        57 non-null     object
#  44  attributes.Corkage                     27 non-null     object
#  45  attributes.BYOBCorkage                 10 non-null     str
#  46  attributes.HairSpecializesIn           6 non-null      str
#  47  attributes.Open24Hours                 1 non-null      object
#  48  attributes.RestaurantsCounterService   1 non-null      object
#  49  attributes.AgesAllowed                 0 non-null      float64
#  50  attributes.DietaryRestrictions         1 non-null      str
#  51  hours.Monday                           1619 non-null   str
#  52  hours.Tuesday                          1724 non-null   str
#  53  hours.Wednesday                        1756 non-null   str
#  54  hours.Thursday                         1780 non-null   str
#  55  hours.Friday                           1775 non-null   str
#  56  hours.Saturday                         1669 non-null   str
#  57  hours.Sunday                           1267 non-null   str
# dtypes: float64(5), int64(3), object(24), str(26)
# memory usage: 972.1+ KB
