# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("data/StateData.csv")
df.head()
# Out:
#         State state_code region    governor               psychRegions  \
# 0     Alabama         AL  South  Republican  Friendly and Conventional
# 1     Arizona         AZ   West  Republican       Relaxed and Creative
# 2    Arkansas         AR  South  Republican  Friendly and Conventional
# 3  California         CA   West    Democrat       Relaxed and Creative
# 4    Colorado         CO   West    Democrat  Friendly and Conventional
#
#    extraversion  agreeableness  conscientiousness  neuroticism  openness  ...  \
# 0          55.5           52.7               55.5         48.7      42.7  ...
# 1          50.6           46.6               58.4         38.1      54.7  ...
# 2          49.9           52.7               41.0         56.2      40.3  ...
# 3          51.4           49.0               43.2         39.1      65.0  ...
# 4          45.3           47.5               58.8         34.3      57.9  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State              48 non-null     object
#  1   state_code         48 non-null     object
#  2   region             48 non-null     object
#  3   governor           48 non-null     object
#  4   psychRegions       48 non-null     object
#  5   extraversion       48 non-null     float64
#  6   agreeableness      48 non-null     float64
#  7   conscientiousness  48 non-null     float64
#  8   neuroticism        48 non-null     float64
#  9   openness           48 non-null     float64
#  10  instagram          48 non-null     float64
#  11  facebook           48 non-null     float64
#  12  retweet            48 non-null     float64
#  13  entrepreneur       48 non-null     float64
#  14  gdpr               48 non-null     float64
#  15  privacy            48 non-null     float64
# ...

# %%
df.describe()
# Out:
#        extraversion  agreeableness  conscientiousness  neuroticism   openness  \
# count     48.000000      48.000000            48.0000    48.000000  48.000000
# mean      49.695833      50.593750            50.1250    50.185417  49.427083
# std        9.862975       9.192166            10.0659    10.030952   9.267117
# min       26.500000      29.800000            24.0000    30.400000  21.800000
# 25%       44.350000      45.775000            43.0500    43.850000  42.700000
# 50%       51.150000      52.050000            51.3500    49.000000  49.850000
# 75%       56.050000      56.625000            56.1250    56.925000  56.675000
# max       69.800000      69.400000            69.6000    79.200000  65.000000
#
#        instagram   facebook    retweet  entrepreneur       gdpr    privacy  \
# count  48.000000  48.000000  48.000000     48.000000  48.000000  48.000000
# mean   -0.033750   0.095625   0.021458      0.034583  -0.025417  -0.092292
# ...

# %%
df['region'] = df['region'].astype('category')
print(df['region'].value_counts())

      #this will bin the dataset.
# Out:
# region
# South        16
# Midwest      12
# West         11
# Northeast     9
# Name: count, dtype: int64

# %%
df. isnull ().sum()
# this seems to be a clean set
# Out:
# State                0
# state_code           0
# region               0
# governor             0
# psychRegions         0
# extraversion         0
# agreeableness        0
# conscientiousness    0
# neuroticism          0
# openness             0
# instagram            0
# facebook             0
# retweet              0
# entrepreneur         0
# gdpr                 0
# privacy              0
# university           0
# mortgage             0
# volunteering         0
# museum               0
# scrapbook            0
# modernDance          0
# dtype: int64

# %%
#barchart for 1 variable

# %%
#import lib
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#generate a bar chat
ax = sns.countplot(data = df, x='region', palette= 'pastel', edgecolor='black', hue='region', legend=True)
#set the title and label
ax.set_title('distro of regions for student admin')
ax.set_xlabel('region')
ax.set_ylabel('freq')
ax.tick_params(axis='x', rotation = 45)

# %% [markdown]
# ## there are 3 steps for freq for numerical data.
# ## determine the number of nonoverlapping bins
# ## determine the width of each bin
# ## determine the bin limits
# ## Find the largest
# ## Find minimum
# ## large-small/the number of bins you want

# %%
sns.histplot(data = df, x='sat_avg', binwidth=30, edgecolor='black')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 sns.histplot(data = df, x='sat_avg', binwidth=30, edgecolor='black')
#
# File /opt/anaconda3/lib/python3.13/site-packages/seaborn/distributions.py:1379, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1358 def histplot(
#    1359     data=None, *,
#    1360     # Vector variables
#    (...)   1376     **kwargs,
#    1377 ):
# -> 1379     p = _DistributionPlotter(
#    1380         data=data,
#    1381         variables=dict(x=x, y=y, hue=hue, weights=weights),
#    1382     )
#    1384     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# ...
